# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def theta1(t: np.array):
    """t: vector columna"""
    
    return t

# %%
def theta2(t: np.array):
    """t: vector columna"""
    
    return t**2

# %%
def radious1(t: np.array):
    
    """t: vector columna"""
    
    return np.ones(t.shape[0])*8

# %%
def radious2(t: np.array):
    
    """t: vector columna"""
    
    return np.log(t)*np.pi

# %%
def circular_movement(theta, radious, t):
    
    angles = theta(t)*np.pi/180
    distance = radious(t)
    
    r_x = distance*np.cos(angles)
    r_y = distance*np.sin(angles)
    
    fig1, ax1 = plt.subplots(1)
    
    ax1.plot(r_x, r_y)
    ax1.set_title("Movimiento circular no uniforme")
    ax1.set_xlabel("Posición en x (mts)")
    ax1.set_ylabel("Posición en y (mts)")
    
    fig2, ax2 = plt.subplots(1)
    ax2.plot(angles, r_x)
    ax2.set_title("Movimiento circular no uniforme")
    ax2.set_xlabel("Angulo (grados)")
    ax2.set_ylabel("Posición en x (mts)")
    
    fig3, ax3 = plt.subplots(1)
    ax3.plot(angles, r_y)
    ax3.set_title("Movimiento circular no uniforme")
    ax3.set_xlabel("Angulo (grados)")
    ax3.set_ylabel("Posición en y (mts)")
    
    
    plt.show()

# %%
circular_movement(theta2, radious2, np.arange(1, 150, step=0.001))
